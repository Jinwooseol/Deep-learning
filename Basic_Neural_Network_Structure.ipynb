# %% [markdown]
# <a href="https://colab.research.google.com/github/Jinwooseol/Deep-learning/blob/main/Basic_Neural_Network_Structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #퍼셉트론
# - Artificial neural network의 한 종류
# - 다수의 input($x_1, x_2, ..., x_n$)과 weight($w_1, w_2, ..., w_n$)를 곱하여 그 값에 bias를 더한 값이 어느 threshold value(𝞗)를 초과하면 activation function을 통과한 output value를 내보냄
# - $y = f(Σ_iw_ix_i + b)$
#   * $f$ : active function
#     - threshold value(𝞡)을 경계로 output이 바뀜
#
#   * $b$ : bias
#     - 결정 경계선을 원점에서부터 벗어나게 해줌
#     - 따로 표현이 없어도 기본적으로 존재
#
#   * $Σ_iw_ix_i$: 두 벡터의 dot product
#     - $x_1w_1 + x_2w_2 + ... + x_nw_n = w^Tx$
#
# ![image.png](data:image/png;base64,...)
#
# Reference: https://untitledtblog.tistory.com/27

# %% [markdown]
# #뉴런의 수학적 표현
# ![image.png](data:image/png;base64,...)
#
# Reference: https://untitledtblog.tistory.com/27

# %% [markdown]
# #Fully-Connected Layer 수학적 표현
# - 모든 Nodes가 서로 edge로 연결된 상태
#
# - Weight set $W = [w_0, w_1, ..., w_{M-1}]^T$ 형태로
#   각각의 $w_k$는 $N$ x 1 형태의 vector, ($W$는 $N$ x $M$ Matrix)
#
# - Bias $b = [b_0, b_1, ..., b_{M-1}]$
#
# - $y_0 = f(w^T_0x + b_0)$
#
# - $y_1 = f(w^T_1x + b_1)$
#
# - $y_2 = f(w^T_2x + b_2)$
#
#   ...
#
# - $y_{M-1} = f(w^T_{M-1}x + b_{M-1})$
#
# → $y = f(Wx + b)$

# %% [markdown]
# #Logic Gate
# - AND, OR, NOT, NAND, NOR 존재
#
#
# #AND gate
# - AND gate를 만족시키는 weights, bias 구하기

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use(['seaborn-whitegrid'])

# %%
def AND(a, b):
  input = np.array([a, b])
  weight = np.array([0.4, 0.4])
  bias = -0.6
  value = np.sum(input * weight) + bias

  if value <= 0:
    return 0
  else:
    return 1

# %%
print(AND(0, 0))
print(AND(0, 1))
print(AND(1, 0))
print(AND(1, 1))
# Out:
# 0
# 0
# 0
# 1

# %%
x1 = np.arange(-2, 2, 0.01)
x2 = np.arange(-2, 2, 0.01)
bias = -0.6

y = (-0.4 * x1 - bias) / 0.4

plt.axvline(x=0, color='k')
plt.axhline(y=0, color='k')

plt.plot(x1, y, 'r--')  # r--은 red 점선, and gate를 결정하기 위한 경계선
plt.scatter(0, 0, color='black', marker='x', s=150)  # s is size
plt.scatter(0, 1, color='black', marker='x', s=150)
plt.scatter(1, 0, color='black', marker='x', s=150)
plt.scatter(1, 1, color='orange', marker='o', s=150)
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)
plt.show()

# %% [markdown]
# #OR Gate
# - OR gate를 만족시키는 weights와 bias 구하기

# %%
def OR(a, b):
  input = np.array([a, b])
  weight = np.array([0.4, 0.5])
  bias = -0.3
  value = np.sum(input * weight) + bias

  if value <= 0:
    return 0
  else:
    return 1

# %%
print(OR(0, 0))
print(OR(0, 1))
print(OR(1, 0))
print(OR(1, 1))
# Out:
# 0
# 1
# 1
# 1

# %%
x1 = np.arange(-2, 2, 0.01)
x2 = np.arange(-2, 2, 0.01)
bias = -0.3

y = (-0.4 * x1 - bias) / 0.5

plt.axvline(x=0, color='k')
plt.axhline(y=0, color='k')

plt.plot(x1, y, 'r--')  # r--은 red 점선, and gate를 결정하기 위한 경계선
plt.scatter(0, 0, color='black', marker='x', s=150)  # s is size
plt.scatter(0, 1, color='orange', marker='o', s=150)
plt.scatter(1, 0, color='orange', marker='o', s=150)
plt.scatter(1, 1, color='orange', marker='o', s=150)
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)
plt.show()

# %% [markdown]
# # NAND Gate

# %%
def NAND(a, b):
  input = np.array([a, b])
  weight = np.array([-0.6, -0.5])
  bias = 0.7
  value = np.sum(input * weight) + bias

  if value <= 0:
    return 0
  else:
    return 1

# %%
print(NAND(0, 0))
print(NAND(0, 1))
print(NAND(1, 0))
print(NAND(1, 1))
# Out:
# 1
# 1
# 1
# 0

# %%
x1 = np.arange(-2, 2, 0.01)
x2 = np.arange(-2, 2, 0.01)
bias = 0.7

y = (0.6 * x1 - bias) / -0.5

plt.axvline(x=0, color='k')
plt.axhline(y=0, color='k')

plt.plot(x1, y, 'r--')  # r--은 red 점선, and gate를 결정하기 위한 경계선
plt.scatter(0, 0, color='orange', marker='o', s=150)  # s is size
plt.scatter(0, 1, color='orange', marker='o', s=150)
plt.scatter(1, 0, color='orange', marker='o', s=150)
plt.scatter(1, 1, color='black', marker='x', s=150)
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)
plt.show()

# %% [markdown]
# #XOR Gate
# - 딥러닝의 첫번째 위기를 초래 (특정 직선 하나로는 결정 불가능)
# → **Multi Layer Perceptron으로 해결 가능**
#
# #Multi Layer Perceptron
# - Input layer과 output layer 사이에 하나이상의 hidden layer가 존재
#   (5개 이상의 hidden layer가 존재하면 Deep Neural Network)
#
#
# >Input layer → hidden layer
# - $z = f_Z(W_Lx + b_L)$
#
# >Hidden layer → output layer
# - $y = a_K(W_Kz + b_K)$

# %% [markdown]
# #XOR Gate 표현

# %%
def XOR(x1, x2):
  s1 = NAND(x1, x2)
  s2 = OR(x1, x2)
  y = AND(s1, s2)
  return y

# %%
print(XOR(0, 0))
print(XOR(0, 1))
print(XOR(1, 0))
print(XOR(1, 1))
# Out:
# 0
# 1
# 1
# 0

# %% [markdown]
# #Activation Function
# - Input signals의 총합에 따라 output signal으로 변환
# - 하나의 layer에서 다음 layer으로 넘어갈 때, 항상 activation function을 통과
#
# > 대표적인 activation function
# - Sigmoid
# - ReLU
# - tanh
# - Identity Function
# - Softmax

# %% [markdown]
# #Step Function
# $y = \left\{\begin{matrix}0
#  & (x < 0) \\1
#  &  (x \geq 0)\\
# \end{matrix}\right.$

# %%
def step_function(x):
  if x > 0:
    return 1
  else:
    return 0

# %%
def step_function_numpy(x):
  y = x > 0
  return y.astype(np.int)

# %%
print(step_function(-3))
print(step_function(5))

a = np.array([5, 3, -4, 2.0])
print(step_function_numpy(a))
# Out:
# 0
# 1
# [1 1 0 1]

# %% [markdown]
# #Sigmoid Function
# - Binary classification에서 주로 사용
#   * 마지막 출력층의 activation function으로 사용
# - 출력값은 0 ~ 1사이, 확률로 표현 가능
#
# $y = \frac{1}{1+e^{-x}}$

# %%
def sigmoid(x):
  return 1/(1+np.exp(-x))

# %%
print(sigmoid(3))
print(sigmoid(-3))
# Out:
# 0.9525741268224334
# 0.04742587317756678

# %%
x = np.arange(-10, 10, 0.01)
y = sigmoid(x)

plt.plot(x, y, 'r-')
plt.show()

# %% [markdown]
# #Sigmoid function Vs. Step function
#
# - Commonalities
#
#   * 출력값의 범위: 0 ~ 1
#   * 입력값의 정도에 따라 출력값의 정도가 달라짐
#
# - Differences
#
#   * Sigmoid function은 입력에 따라 출력이 연속적으로 변화
#   * 따라서, 모든 점에서 **미분 가능**

# %%
x = np.arange(-5.0, 5.0, 0.01)
y1 = sigmoid(x)
y2 = step_function_numpy(x)
plt.plot(x, y1, 'r-', x, y2, 'b-')
plt.show()

# %% [markdown]
# #ReLU(Rectified Linear Unit)
# - 가장 많이 쓰이는 function중 하나
# - 0 이전까지는 0으로 값 유지, 0보다 크면 input value
# - $y = \left\{\begin{matrix}0
#  & (x \le 0) \\x
#  &  (x > 0)\\
# \end{matrix}\right.$

# %%
def ReLU(x):
  if x > 0:
    return x
  else:
    return 0

# %%
def ReLU_numpy(x):
  return x * (x > 0)

# %%
print(ReLU(5))
print(ReLU(-3))
# Out:
# 5
# 0

# %%
x = np.arange(-5.0, 5.0, 0.01)
y = ReLU_numpy(x)

plt.plot(x, y, 'r-')
plt.show()

# %% [markdown]
# #tanh (Hyperbolic tangent function)
# - $y = \frac{e^x - e^{-x}}{e^x + e^{-x}}$

# %%
def tanh(x):
  return (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x))

# %%
print(tanh(3))
print(tanh(-3))
# Out:
# 0.9950547536867306
# -0.9950547536867306

# %%
x = np.arange(-5, 5, 0.01)
y = tanh(x)

plt.plot(x, y, 'r-')
plt.axvline(x=0, color='k')
plt.axhline(y=0, color='k')
plt.show()

# %% [markdown]
# #Identity Function
# - Regression 문제에서 주로 사용
#   * Output layer의 activation function으로 활용
#
# - $y = x$
#
# - Input value와 output value가 같아 정의할 필요는 없으나, neural network 중간 layer의 흐름과 통일시키기 위해 사용

# %%
def identity_function(x):
  return x

# %%
x = np.arange(-5, 5, 0.01)
y = identity_function(x)

plt.plot(x, y, 'r-')
plt.axvline(x=0, color='k')
plt.axhline(y=0, color='k')
plt.show()

# %% [markdown]
# #Softmax
# - Multi class classification에서 사용
# - Input value의 영향을 크게 받음
# - Output value를 **확률**에 대응가능
# - Output value의 총합은 1
# - $y_k = \frac{e^{a_k}}{Σ_je^{a_j}}$

# %%
def softmax(a):
 exp_a = np.exp(a)
 sum_exp_a = np.sum(exp_a)
 y = exp_a / sum_exp_a
 return y

# %%
a = np.array([0.3, 0.2, 4.0, -1.2])
print(softmax(a))
print(np.sum(softmax(a)))
# Out:
# [0.02348781 0.02125265 0.9500187  0.00524084]
# 1.0

# %% [markdown]
# #Softmax의 주의점
# - Overflow 문제 발생
# - Exponential function을 사용하기 때문에 input value가 너무 큰 경우, 무한대 (inf)가 반환
#
#   개선된 수식
#   - $y_k = \frac{Ce^{a_k}}{CΣ_je^{a_j}}$ = $\frac{e^{(a_k + logC)}}{Σ_je^{(a_j + logC)}}$ = $\frac{e^{(a_k + C')}}{Σ_je^{(a_j + C')}}$
#   (C'는 -(가장 큰 입력값))

# %%
a = np.array([500, 600, 700, 1000])
print(softmax(a))  # Overflow 발생
# Out:
# [ 0.  0.  0. nan]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in true_divide
#   after removing the cwd from sys.path.

# %%
def adv_softmax(a):
  C = np.max(a)
  return(np.exp(a - C) / np.sum(np.exp(a - C)))

# %%
a = np.array([500, 600, 700, 1000])
print(adv_softmax(a))
# Out:
# [7.12457641e-218 1.91516960e-174 5.14820022e-131 1.00000000e+000]

# %%
x = np.arange(-5.0, 5.0, 0.01)
y = adv_softmax(x)

plt.plot(x, y, 'r-')
plt.show()

# %% [markdown]
# #activation function을 non-linear function으로 사용하는 이유
# - Neural network를 deep하기 만듦
# - Linear function을 사용하면 hidden layer의 수가 의미가 없어짐
#   Linear function을 합성함수는 여전히 linear function이기 때문이다.

# %% [markdown]
# #LeakyReLU
# - ReLU의 변형으로 0이하의 입력에 대해서도 값의 변화 존재
# - $f_a(x) = \left\{\begin{matrix}x
#  & (x \ge 0) \\ax
#  &  (x < 0)\\
# \end{matrix}\right.$

# %%
def LeakyReLU(x):
  a = 0.1
  return np.maximum(a*x, x)

# %%
x = np.arange(-5.0, 5.0, 0.01)
y = LeakyReLU(x)

plt.plot(x, y, 'r-')
plt.show()

# %% [markdown]
# #ELU (Exponential Linear Units)
# - $f(α, x) = \left\{\begin{matrix}x
#  & (x > 0) \\α(e^x - 1)
#  &  (x ≤ 0)\\
# \end{matrix}\right.$

# %%
def ELU(x):
  alpha = 1.0
  return (x >= 0) * x + (x < 0) * alpha * (np.exp(x) - 1)

# %%
x = np.arange(-5.0, 5.0, 0.01)
y = ELU(x)

plt.plot(x, y, 'r-')
plt.axhline(y=0, color='k')
plt.show()

# %% [markdown]
# #Activation Function 참고
# - 일반적인 사용 순서
#
#   1. ELU
#   2. LeakyReLU
#   3. ReLU
#   4. tanh
#   5. sigmoid
#
# - Stanford에서 언급한 사용 순서
#
#   1. ReLU
#   2. ReLU Family(LeakyReLU, ELU)
#   3. sigmoid는 사용 X

# %% [markdown]
# # Three Layers Neural Network (practice)
# - 2 class 분류
#
# - **Input Layer**
#   - Number of Nodes: 3
#
# - **Hidden Layers**
#   * First hidden layer
#     - Number of Nodes: 3
#   * Second hidden layer
#     - Number of Nodes: 2
#
# - **Output Layer**
#   * Number of Nodes: 2

# %% [markdown]
# #Define Activation Function

# %%
def sigmoid(x):
  return 1 / (1 + np.exp(-x))

# %%
# Input layer -> first hidden layer
X = np.array([1.0, 0.5, 0.4])
W1 = np.array([[0.1, 0.3, 0.5], [0.2, 0.4, 0.6], [0.3, 0.5, 0.7]])
B1 = np.array([1, 1, 1])

print("X's shape: ", X.shape)
print("W1's shape: ", W1.shape)
print("B1's shape: ", B1.shape)

A1 = np.dot(X, W1) + B1   # activation function 통과 전
Z1 = sigmoid(A1)          # activation function 통과 후

print(A1)
print(Z1)
# Out:
# X's shape:  (3,)
# W1's shape:  (3, 3)
# B1's shape:  (3,)
# [1.32 1.7  2.08]
# [0.78918171 0.84553473 0.88894403]

# %%
# First hidden layer -> second hidden layer
W2 = np.array([[0.2, 0.4, 0.6], [0.1, 0.3, 0.5], [0.4, 0.6, 0.8]])
B2 = np.array([1, 1, 1])

print("W2's shape: ", W2.shape)
print("B2's shape: ", B2.shape)

A2 = np.dot(Z1, W2) + B2
Z2 = sigmoid(A2)

print(A2)
print(Z2)
# Out:
# W2's shape:  (3, 3)
# B2's shape:  (3,)
# [1.59796743 2.10269952 2.60743162]
# [0.83173411 0.89116528 0.93133834]

# %%
# Second hidden layer -> Output layer
W3 = np.array([[0.1, 0.3], [-0.1, -0.5], [0.3, 0.5]])
B3 = np.array([1, 1])

print("W3's shape: ", W3.shape)
print("B3's shape: ", B3.shape)

A3 = np.dot(Z2, W3) + B3
Z3 = sigmoid(A3)

print(A3)
print(Z3)
# Out:
# W3's shape:  (3, 2)
# B3's shape:  (2,)
# [1.27345838 1.26960676]
# [0.78133419 0.78067542]

# %%
# Output layer -> Output
W4 = np.array([[0.1, 0.2], [0.3, 0.5]])
B4 = np.array([1, 1])

print("W4's shape: ", W4.shape)
print("B4's shape: ", B4.shape)

A4 = np.dot(Z3, W4) + B4
Z4 = sigmoid(A4)

print(A4)
print(Z4)
# Out:
# W4's shape:  (2, 2)
# B4's shape:  (2,)
# [1.31233605 1.54660455]
# [0.7879038  0.82442278]

# %% [markdown]
# #하나로 합치기

# %%
def network():
  
  network = {}
  
  # First Layer 
  network['W1'] = np.array([[0.1, 0.3, 0.5], [0.2, 0.4, 0.6], [0.3, 0.5, 0.7]])
  network['B1'] = np.array([1, 1, 1])

  # Second Layer 
  network['W2'] = np.array([[0.2, 0.4, 0.6], [0.1, 0.3, 0.5], [0.4, 0.6, 0.8]])
  network['B2'] = np.array([1, 1, 1])

  # Third Layer 
  network['W3'] = np.array([[0.1, 0.3], [-0.1, -0.5], [0.3, 0.5]])
  network['B3'] = np.array([1, 1])

  # Forth Layer 
  network['W4'] = np.array([[0.1, 0.2], [0.3, 0.5]])
  network['B4'] = np.array([1, 1])

  return network

# %%
def forward(network, x):
  W1, W2, W3, W4 = network['W1'], network['W2'], network['W3'], network['W4']
  B1, B2, B3, B4 = network['B1'], network['B2'], network['B3'], network['B4']

  # (Input layer -> first hidden layer)
  A1 = np.dot(x, W1) + B1
  Z1 = sigmoid(A1)

  # (First hidden layer -> second hidden layer)
  A2 = np.dot(Z1, W2) + B2
  Z2 = sigmoid(A2)

  # (Second hidden layer -> Output layer)
  A3 = np.dot(Z2, W3) + B3
  Z3 = sigmoid(A3)

  # (Output layer -> Output)
  A4 = np.dot(Z3, W4) + B4
  y = sigmoid(A4)

  return y

# %% [markdown]
# #Neural Network 추론 실행

# %%
net = network()
x = np.array([0.3, 1.3, -2.2])
y = forward(net, x)
print(y)
# Out:
# [0.78781193 0.82428264]
